# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv('clean.csv', index_col=0)
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
# get date
df['date'] = df['time'].dt.date

# get day
df['day'] = df['time'].dt.weekday

# get month
df['month'] = df['time'].dt.month

df
# Out:
#              id                    time        variable   value        date  \
# 0       AS14.01 2014-02-26 13:00:00.000            mood   6.000  2014-02-26
# 1       AS14.01 2014-02-26 15:00:00.000            mood   6.000  2014-02-26
# 2       AS14.01 2014-02-26 18:00:00.000            mood   6.000  2014-02-26
# 3       AS14.01 2014-02-26 21:00:00.000            mood   7.000  2014-02-26
# 4       AS14.01 2014-02-27 09:00:00.000            mood   6.000  2014-02-27
# ...         ...                     ...             ...     ...         ...
# 370770  AS14.30 2014-04-11 07:51:16.948  appCat.weather   8.032  2014-04-11
# 370771  AS14.30 2014-04-19 11:00:32.747  appCat.weather   3.008  2014-04-19
# 370772  AS14.30 2014-04-26 10:19:07.434  appCat.weather   7.026  2014-04-26
# 370773  AS14.30 2014-04-27 00:44:48.450  appCat.weather  23.033  2014-04-27
# 370774  AS14.32 2014-04-07 18:25:14.036  appCat.weather  22.431  2014-04-07
#
#         day  month
# 0         2      2
# 1         2      2
# 2         2      2
# 3         2      2
# 4         3      2
# ...     ...    ...
# 370770    4      4
# 370771    5      4
# 370772    5      4
# 370773    6      4
# 370774    0      4
#
# [370775 rows x 7 columns]

# %%
aggregations = {'mood':'mean', 
                'circumplex.arousal':'mean', 
                'circumplex.valence':'mean', 
                'activity':'mean',
                'screen':'sum',
                'call':'sum',
                'sms':'sum',
                'appCat.builtin':'sum',
                'appCat.communication':'sum',
                'appCat.entertainment':'sum',
                'appCat.finance':'sum',
                'appCat.game':'sum',
                'appCat.office':'sum',
                'appCat.other':'sum',
                'appCat.social':'sum',
                'appCat.travel':'sum',
                'appCat.unknown':'sum',
                'appCat.utilities':'sum',
                'appCat.weather':'sum',}

df_agg = pd.DataFrame(columns=['id', 'date'])

for variable, aggregation in aggregations.items():
    df_new = df[df['variable']==variable].groupby(['id', 'date']).value.agg([aggregation])
    df_new = df_new.rename(columns={aggregation:f'{variable}_{aggregation}'}).reset_index()
    df_agg = pd.merge(df_agg, df_new, on=['id', 'date'], how='outer')

df_dates = df[['date', 'day', 'month']].drop_duplicates()
df_agg = pd.merge(df_agg, df_dates, on=['date'], how='left')

df_agg = df_agg.sort_values(['id', 'date'])

df_agg.to_csv('dataset_aggregated.csv')
df_agg
# Out:
#            id        date  mood_mean  circumplex.arousal_mean  \
# 1309  AS14.01  2014-02-17        NaN                      NaN
# 1310  AS14.01  2014-02-18        NaN                      NaN
# 1311  AS14.01  2014-02-19        NaN                      NaN
# 1312  AS14.01  2014-02-20        NaN                      NaN
# 1886  AS14.01  2014-02-21        NaN                      NaN
# ...       ...         ...        ...                      ...
# 1259  AS14.33  2014-05-27       6.20                 1.000000
# 1260  AS14.33  2014-05-28       7.75                 1.333333
# 1261  AS14.33  2014-05-29       7.00                      NaN
# 1262  AS14.33  2014-05-30       6.80                 0.500000
# 1263  AS14.33  2014-05-31       7.00                      NaN
#
#       circumplex.valence_mean  activity_mean   screen_sum  call_sum  sms_sum  \
# 1309                      NaN            NaN          NaN       2.0      NaN
# 1310                      NaN            NaN          NaN       1.0      NaN
# 1311                      NaN            NaN          NaN       7.0      2.0
# 1312                      NaN            NaN          NaN       2.0      3.0
# 1886                      NaN            NaN          NaN       NaN      1.0
# ...                       ...            ...          ...       ...      ...
# 1259                     0.75       0.012704  3344.624001       1.0      2.0
# 1260                     1.20       0.103301  6757.439998      10.0      1.0
# 1261                     1.00       0.149544   560.093000       5.0      1.0
# 1262                     0.50       0.142046  8649.867999       4.0      NaN
# 1263                     1.00            NaN          NaN       NaN      NaN
#
#       appCat.builtin_sum  ...  appCat.game_sum  appCat.office_sum  \
# 1309                 NaN  ...              NaN                NaN
# 1310                 NaN  ...              NaN                NaN
# 1311                 NaN  ...              NaN                NaN
# 1312                 NaN  ...              NaN                NaN
# 1886                 NaN  ...              NaN                NaN
# ...                  ...  ...              ...                ...
# 1259             726.391  ...              NaN                NaN
# 1260            2551.046  ...              NaN            357.909
# 1261             400.034  ...              NaN                NaN
# 1262            3044.030  ...              NaN                NaN
# 1263                 NaN  ...              NaN                NaN
#
#       appCat.other_sum  appCat.social_sum  appCat.travel_sum  \
# 1309               NaN                NaN                NaN
# 1310               NaN                NaN                NaN
# 1311               NaN                NaN                NaN
# 1312               NaN                NaN                NaN
# 1886               NaN                NaN                NaN
# ...                ...                ...                ...
# 1259           142.686           2010.364                NaN
# 1260           529.946           4446.281                NaN
# 1261            29.202           1789.922              0.939
# 1262            52.610           3166.409           1052.648
# 1263               NaN                NaN                NaN
#
#       appCat.unknown_sum  appCat.utilities_sum  appCat.weather_sum  day  month
# 1309                 NaN                   NaN                 NaN    0      2
# 1310                 NaN                   NaN                 NaN    1      2
# 1311                 NaN                   NaN                 NaN    2      2
# 1312                 NaN                   NaN                 NaN    3      2
# 1886                 NaN                   NaN                 NaN    4      2
# ...                  ...                   ...                 ...  ...    ...
# 1259                 NaN                56.173                 NaN    1      5
# 1260                 NaN                30.666                 NaN    2      5
# 1261                 NaN                 3.199                 NaN    3      5
# 1262               8.072               232.825                 NaN    4      5
# 1263                 NaN                   NaN                 NaN    5      5
#
# [1973 rows x 23 columns]

# %%
df_agg[df_agg['screen_sum'].isna() & ~df_agg['appCat.social_sum'].isna()]
# Out:
#           id        date  mood_mean  circumplex.arousal_mean  \
# 230  AS14.06  2014-05-08        7.0                      NaN
#
#      circumplex.valence_mean  activity_mean  screen_sum  call_sum  sms_sum  \
# 230                      1.0            0.0         NaN       NaN      NaN
#
#      appCat.builtin_sum  ...  appCat.game_sum  appCat.office_sum  \
# 230                 NaN  ...              NaN                NaN
#
#      appCat.other_sum  appCat.social_sum  appCat.travel_sum  \
# 230               NaN             63.596                NaN
#
#      appCat.unknown_sum  appCat.utilities_sum  appCat.weather_sum  day  month
# 230                 NaN                   NaN                 NaN    3      5
#
# [1 rows x 23 columns]
