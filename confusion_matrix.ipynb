# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

df_pred = pd.read_csv('ts_classification.csv', index_col=0)
Y_test_class_actual = df_pred[df_pred['test']==1]['actual']
Y_test_class_pred = df_pred[df_pred['test']==1]['predicted']

conf_matrix = confusion_matrix(Y_test_class_actual, Y_test_class_pred)
df = pd.DataFrame(conf_matrix, columns=[5, 6, 7, 8, 9], index=[5, 6, 7, 8, 9])

cm = sns.light_palette("red", as_cmap=True)
df.style\
    .background_gradient(cmap=cm, axis=1)\
    .set_precision(0)
# Out:
# C:\Users\mylen\AppData\Local\Temp\ipykernel_26392\1515856493.py:16: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .set_precision(0)
# <style type="text/css">
# #T_eeafd_row0_col0, #T_eeafd_row0_col1, #T_eeafd_row0_col3, #T_eeafd_row0_col4, #T_eeafd_row1_col0, #T_eeafd_row1_col4, #T_eeafd_row2_col0, #T_eeafd_row2_col4, #T_eeafd_row3_col0, #T_eeafd_row3_col4, #T_eeafd_row4_col0, #T_eeafd_row4_col1, #T_eeafd_row4_col3, #T_eeafd_row4_col4 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_eeafd_row0_col2, #T_eeafd_row1_col2, #T_eeafd_row2_col2, #T_eeafd_row3_col2, #T_eeafd_row4_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_eeafd_row1_col1 {
#   background-color: #fd2525;
#   color: #f1f1f1;
# }
# #T_eeafd_row1_col3 {
#   background-color: #f5cbcb;
#   color: #000000;
# }
# #T_eeafd_row2_col1 {
#   background-color: #f4dcdc;
#   color: #000000;
# }
# #T_eeafd_row2_col3 {
#   background-color: #f5cdcd;
#   color: #000000;
# }
# #T_eeafd_row3_col1 {
#   background-color: #f3e8e7;
#   color: #000000;
# }
# #T_eeafd_row3_col3 {
#   background-color: #fa6767;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eeafd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeafd_level0_col0" class="col_heading level0 col0" >5</th>
#       <th id="T_eeafd_level0_col1" class="col_heading level0 col1" >6</th>
#       <th id="T_eeafd_level0_col2" class="col_heading level0 col2" >7</th>
#       <th id="T_eeafd_level0_col3" class="col_heading level0 col3" >8</th>
#       <th id="T_eeafd_level0_col4" class="col_heading level0 col4" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeafd_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_eeafd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_eeafd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_eeafd_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_eeafd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_eeafd_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeafd_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_eeafd_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_eeafd_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_eeafd_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_eeafd_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_eeafd_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeafd_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_eeafd_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_eeafd_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_eeafd_row2_col2" class="data row2 col2" >82</td>
#       <td id="T_eeafd_row2_col3" class="data row2 col3" >12</td>
#       <td id="T_eeafd_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeafd_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_eeafd_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_eeafd_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_eeafd_row3_col2" class="data row3 col2" >28</td>
#       <td id="T_eeafd_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_eeafd_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeafd_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_eeafd_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_eeafd_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_eeafd_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_eeafd_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_eeafd_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
random_forest = [[0,1,0,0,0],[0,7,12,0,0],[0,3,48,7,0],[0,0,16,14,0],[0,0,0,3,0]]
df = pd.DataFrame(random_forest, columns=[5, 6, 7, 8, 9], index=[5, 6, 7, 8, 9])

cm = sns.light_palette("red", as_cmap=True)
df.style\
    .background_gradient(cmap=cm, axis=1)\
    .set_precision(0)
# Out:
# C:\Users\mylen\AppData\Local\Temp\ipykernel_26392\3516116415.py:7: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .set_precision(0)
# <style type="text/css">
# #T_4c0e0_row0_col0, #T_4c0e0_row0_col2, #T_4c0e0_row0_col3, #T_4c0e0_row0_col4, #T_4c0e0_row1_col0, #T_4c0e0_row1_col3, #T_4c0e0_row1_col4, #T_4c0e0_row2_col0, #T_4c0e0_row2_col4, #T_4c0e0_row3_col0, #T_4c0e0_row3_col1, #T_4c0e0_row3_col4, #T_4c0e0_row4_col0, #T_4c0e0_row4_col1, #T_4c0e0_row4_col2, #T_4c0e0_row4_col4 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_4c0e0_row0_col1, #T_4c0e0_row1_col2, #T_4c0e0_row2_col2, #T_4c0e0_row3_col2, #T_4c0e0_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_4c0e0_row1_col1 {
#   background-color: #fa6464;
#   color: #f1f1f1;
# }
# #T_4c0e0_row2_col1 {
#   background-color: #f4e1e1;
#   color: #000000;
# }
# #T_4c0e0_row2_col3 {
#   background-color: #f5cdcd;
#   color: #000000;
# }
# #T_4c0e0_row3_col3 {
#   background-color: #fe1d1d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c0e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c0e0_level0_col0" class="col_heading level0 col0" >5</th>
#       <th id="T_4c0e0_level0_col1" class="col_heading level0 col1" >6</th>
#       <th id="T_4c0e0_level0_col2" class="col_heading level0 col2" >7</th>
#       <th id="T_4c0e0_level0_col3" class="col_heading level0 col3" >8</th>
#       <th id="T_4c0e0_level0_col4" class="col_heading level0 col4" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c0e0_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_4c0e0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4c0e0_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_4c0e0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_4c0e0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4c0e0_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e0_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_4c0e0_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_4c0e0_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_4c0e0_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_4c0e0_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_4c0e0_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e0_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_4c0e0_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_4c0e0_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_4c0e0_row2_col2" class="data row2 col2" >48</td>
#       <td id="T_4c0e0_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_4c0e0_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e0_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_4c0e0_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_4c0e0_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_4c0e0_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_4c0e0_row3_col3" class="data row3 col3" >14</td>
#       <td id="T_4c0e0_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e0_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_4c0e0_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_4c0e0_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_4c0e0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_4c0e0_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_4c0e0_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>
